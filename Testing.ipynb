# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavtope11/Cnn_Cats_v_Dogs/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import tensorflow as tf

CATEGORIES = ["Dog", "Cat"]


def prepare(filepath):
    IMG_SIZE = 100
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f55dce57-42e3-4901-a0a3-c75c1e2c7f2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f55dce57-42e3-4901-a0a3-c75c1e2c7f2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpeg to cat.jpeg
# ...

# %%
from keras.models import load_model
model = load_model('64x3-CNN.h5')

# %%
prediction = model.predict([prepare('/content/drive/My Drive/Colab/cat2.jpeg')])
print(prediction)
print(CATEGORIES[int(prediction[0][0])])
# Out:
# [[1.]]
# Cat
